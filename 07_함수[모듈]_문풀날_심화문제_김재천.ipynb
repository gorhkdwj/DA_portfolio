# %% [markdown]
# <a href="https://colab.research.google.com/github/gorhkdwj/DA_Portfolio/blob/P_S_Deep/07_%ED%95%A8%EC%88%98%5B%EB%AA%A8%EB%93%88%5D_%EB%AC%B8%ED%92%80%EB%82%A0_%EC%8B%AC%ED%99%94%EB%AC%B8%EC%A0%9C_%EA%B9%80%EC%9E%AC%EC%B2%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 문제 1
# ## 수정!
#
# **온라인 강의 수강생 관리 시스템**
#
# 다음 구조의 데이터를 사용한다.
#
# ```python
# students = {
#     "민수": [80, 70, 90],
#     "영희": [40, 55, 60],
#     "지수": [100, 95, 90],
#     "철수": [30, 45, 20]
# }
#
# ```
#
# 아래 기능을 함수로 나누어 구현하세요.
#
# 필수 함수:
#
# 1. 한 학생의 평균 점수를 계산하는 함수
# 2. 모든 학생의 평균을 딕셔너리로 만드는 함수
# 3. 평균이 60 이상인 학생만 새 딕셔너리로 반환하는 함수
# 4. 평균이 가장 높은 학생의 이름을 반환하는 함수
#
# 출력 예시:
#
# ```
# 학생별 평균: {'민수': 80.0, '영희': 51.6, '지수': 95.0, '철수': 31.6}
# 합격자: {'민수': 80.0, '지수': 95.0}
# 최고 평균 학생: 지수
#
# ```
#
# 조건:
#
# - 원본 students는 절대 변경되면 안 됨
# - 최소 20줄 이상

# %% [markdown]
# ### 문제 2
#
# **은행 계좌 시뮬레이터**
#
# 다음 구조를 사용한다.
#
# ```python
# accounts = {
#     "A001": 50000,
#     "A002": 120000,
#     "A003": 30000
# }
#
# ```
#
# 다음 기능을 함수로 구현하세요.
#
# 필수 기능:
#
# 1. 입금 함수
# 2. 출금 함수 (잔액 부족 시 출금 실패 처리)
# 3. 전체 잔액 합계 계산 함수
# 4. 잔액이 50000 미만인 계좌만 모아 반환하는 함수
#
# 출력 예시:
#
# ```
# A001 잔액: 70000
# A003 출금 실패
# 전체 은행 자산: 220000
# 위험 계좌: ['A003']
#
# ```
#
# 조건:
#
# - 함수 안에서 딕셔너리를 직접 수정해야 함
# - 매개변수로 딕셔너리를 전달해서 처리
# - 20줄 이상

# %% [markdown]
# ### 문제 3
#
# **텍스트 로그 분석기**
#
# 아래 문자열이 로그 데이터다.
#
# ```python
# log = "error login success login error logout success login error"
#
# ```
#
# 아래 기능을 함수로 구현하세요.
#
# 필수 기능:
#
# 1. 단어별 횟수를 딕셔너리로 만드는 함수
# 2. 가장 많이 나온 단어를 반환하는 함수
# 3. 특정 단어의 비율(%)을 계산하는 함수
# 4. 횟수가 2회 이상인 단어만 새 딕셔너리로 반환하는 함수
#
# 출력 예시:
#
# ```
# 단어 빈도: {'error': 3, 'login': 3, 'success': 2, 'logout': 1}
# 최다 단어: error
# error 비율: 33.3%
# 중요 단어: {'error': 3, 'login': 3, 'success': 2}
#
# ```
#
# 조건:
#
# - 문자열 → 리스트 → 딕셔너리 흐름을 함수로 분리
# - 최소 20줄 이상
