# %%
import pandas as pd

# %%
df_2018 = pd.read_csv("../data/2018.csv", encoding="euc-kr")
df_2019 = pd.read_csv("../data/2019.csv", encoding="euc-kr")
df_2020 = pd.read_csv("../data/2020.csv", encoding="euc-kr")
df_2021 = pd.read_csv("../data/2021.csv", encoding="euc-kr")
df_2022 = pd.read_csv("../data/2022.csv", encoding="euc-kr")
df_2023 = pd.read_csv("../data/2023.csv", encoding="euc-kr")
df_2024 = pd.read_csv("../data/2024.csv", encoding="euc-kr")
df_total = pd.read_csv("../data/real_estate_total.csv", encoding="euc-kr")
# Out:
# C:\Users\gorhk\AppData\Local\Temp\ipykernel_53796\2728381457.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2019 = pd.read_csv("../data/2019.csv", encoding="euc-kr")
# C:\Users\gorhk\AppData\Local\Temp\ipykernel_53796\2728381457.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv("../data/2020.csv", encoding="euc-kr")
# C:\Users\gorhk\AppData\Local\Temp\ipykernel_53796\2728381457.py:4: DtypeWarning: Columns (7,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv("../data/2021.csv", encoding="euc-kr")
# C:\Users\gorhk\AppData\Local\Temp\ipykernel_53796\2728381457.py:7: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2024 = pd.read_csv("../data/2024.csv", encoding="euc-kr")
# ...

# %%
print("2018")
print(df_2018.info())
print("2019")
print(df_2019.info())
print("2020")
print(df_2020.info())
print("2021")
print(df_2021.info())
print("2022")
print(df_2022.info())
print("2023")
print(df_2023.info())
print("2024")
print(df_2024.info())
print("total")
print(df_total.info())
# Out:
# 2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166717 entries, 0 to 166716
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   접수연도              166717 non-null  int64
#  1   자치구코드             166717 non-null  int64
#  2   자치구명              166717 non-null  object
#  3   법정동코드             166717 non-null  int64
#  4   법정동명              166717 non-null  object
#  5   지번구분              152354 non-null  float64
#  6   지번구분명             152354 non-null  object
#  7   본번                152351 non-null  float64
#  8   부번                152351 non-null  float64
#  9   건물명               152371 non-null  object
#  10  계약일               166717 non-null  int64
#  11  물건금액(만원)          166717 non-null  int64
#  12  건물면적(㎡)           166717 non-null  float64
#  13  토지면적(㎡)           142887 non-null  float64
#  14  층                 152371 non-null  float64
# ...

# %%
df_total.head(100)
# Out:
#     접수연도  자치구코드  자치구명  법정동코드 법정동명  지번구분 지번구분명      본번    부번              건물명  \
# 0   2018  11500   강서구  10300  화곡동   1.0    대지  1159.0   0.0    우장산아이파크,이편한세상
# 1   2018  11410  서대문구  11200  대현동   1.0    대지   144.0   0.0             럭키대현
# 2   2018  11590   동작구  10700  사당동   1.0    대지   169.0  32.0               현대
# 3   2018  11350   노원구  10500  상계동   1.0    대지  1380.0   4.0             초산빌라
# 4   2018  11380   은평구  11000  증산동   1.0    대지   189.0  63.0     궁전맨션(189-63)
# ..   ...    ...   ...    ...  ...   ...   ...     ...   ...              ...
# 95  2018  11560  영등포구  13200  신길동   1.0    대지  1583.0   1.0      보라매 SK VIEW
# 96  2018  11530   구로구  10700  개봉동   NaN   NaN     NaN   NaN              NaN
# 97  2018  11350   노원구  10400  하계동   1.0    대지   256.0  13.0          삼정 이오니아
# 98  2018  11680   강남구  10100  역삼동   1.0    대지   709.0   5.0          테헤란아이파크
# 99  2018  11440   마포구  11400  창전동   1.0    대지    27.0  19.0  마포 웨스트리버 태영 데시앙
#
# ...
