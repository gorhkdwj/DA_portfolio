# %% [markdown]
# **Q6. 더 큰 수 반환 함수** 🧰 필수
#
# 두 수 `a`, `b`를 받아 더 큰 값을 반환하는 함수 `bigger(a, b)`를 작성하세요.
#
# (두 수가 같다면 어떤 수가 나와도 됨.)
#
# - 예: `bigger(3, 5)` → `5`
#
# def bigger(a, b):
#
# print(a)

# %%
def bigger(a,b):
    if a>b:
        return a
    elif a<b:
        return b
    else:
        print("두 수가 같습니다.")
        

print(bigger(3, 5))
# Out:
# 5

# %% [markdown]
# **Q7. return 오류 디버깅** 🧰 필수
#
# 아래 함수가 의도대로 동작하지 않는 이유를 1~2문장**(이유, 반환값은 무엇?)**으로 설명하고, 올바르게 수정하세요.
#
# ( 의도 : `10` 출력 )
#
# ```python
# def double(n):
#     n * 2
#
# result = double(5)
# print(result)
# ```

# %%
# return 값이 없어서 함수는 내부 계산만 마치고 None을 뱉는다.
def double(n):
    return n * 2

result = double(5)
print(result)
# Out:
# 10

# %% [markdown]
# **Q8. 0 입력 시 종료하는 누적합 프로그램** 🧰 필수
#
# 사용자에게 **정수를** 계속 입력받아 합을 누적하세요.
#
# - 단, **0을 입력하면 종료**
# - **0은 합계에 포함하지 않음**
# - 종료 후 합계를 출력

# %%
nums = []
while True:
    a = int(input("정수를 입력하세요(종료: 0)"))
    if a == 0:
        break
    else:
        nums.append(a)

print(sum(nums))
# Out:
# 20

# %%
# 원 코드는 scores가 클래스 변수로 생성되어 s1과 s2가 같은 scores=[]를 공유함.
# 그로 인해 s1, s2 각각에 append해도 하나의 scores 리스트에 값을 추가.

# 따라서 아래와 같이 init을 통해 scores를 인스턴스 변수로 만들어줘야함.

class Student:
    def __init__(self):
        self.scores = []

    def add_score(self, score):
        self.scores.append(score)

s1 = Student()
s2 = Student()

s1.add_score(90)
s2.add_score(80)

print(s1.scores)
print(s2.scores)
# Out:
# [90]
# [80]

# %%
def cc(n): 
    cnt= 0 
    while n!=0:
        n= int(input())
        cnt += n
    return cnt
n= int(input())
result = cc(n)
print(result)
# Out:
# 15
