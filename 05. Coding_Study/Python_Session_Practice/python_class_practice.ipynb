# %% [markdown]
# # 🐍 파이썬 클래스(Class) 1~2시간 완성 실습
#
# 재천님, 데이터 분석을 위한 파이썬의 핵심, **'클래스(Class)'** 학습을 환영합니다!
# 이 노트는 개념 설명과 실습 코드가 섞여 있어, 직접 코드를 실행하며 익힐 수 있도록 구성되어 있습니다.
#
# ---
#
# ### 💡 학습 포인트
# 1. **붕어빵 틀(Class)과 붕어빵(Instance)** 의 관계 이해하기
# 2. **`__init__` (초기화 함수)** 의 역할 알기
# 3. **`self` (나 자신)** 의 의미 깨닫기

# %% [markdown]
# ---
# ## 1교시: 개념 잡기 (붕어빵 이론)
#
# ### 1. 클래스와 인스턴스
# * **클래스(Class)**: 설계도, 틀 (예: `Dog`)
# * **인스턴스(Instance)**: 실제 객체 (예: `my_dog`, `your_dog`)
#
# 가장 먼저, 아무 기능이 없는 껍데기 클래스를 만들어 봅시다.

# %%
# 1. Dog 클래스 정의 (설계도 만들기)
class Dog:
    pass  # 아무것도 안 하고 넘어간다는 뜻입니다.

# 2. 인스턴스 생성 (강아지 입양)
my_dog = Dog()
your_dog = Dog()

# 3. 확인해보기
print("my_dog:", my_dog)
print("your_dog:", your_dog)
print("두 강아지는 같은가요?", my_dog == your_dog)

# %% [markdown]
# > **해설**: 결과의 `0x...` 주소값이 서로 다른 것을 볼 수 있습니다. 같은 틀(Class)에서 나왔지만 서로 다른 존재(Instance)라는 뜻입니다.

# %% [markdown]
# ---
# ## 2교시: 구조 만들기
#
# ### 2. 속성(Attribute) 추가하기 (`__init__`)
# 강아지마다 이름과 나이가 다르겠죠? 태어날 때(생성될 때) 이를 정해주는 것이 `__init__` 메서드입니다.

# %%
class Dog:
    # 초기화 함수: 태어날 때 이름과 나이를 받습니다.
    def __init__(self, name, age):
        self.name = name  # 내 이름(self.name)에 전달받은 이름(name)을 저장
        self.age = age    # 내 나이(self.age)에 전달받은 나이(age)를 저장

# 뭉치(3살)와 뽀삐(5살) 입양
dog1 = Dog("뭉치", 3)
dog2 = Dog("뽀삐", 5)

print(f"{dog1.name}는 {dog1.age}살입니다.")
print(f"{dog2.name}는 {dog2.age}살입니다.")

# %% [markdown]
# ### 3. 행동(Method) 만들기
# 강아지가 할 수 있는 행동을 함수로 정의해 봅시다. 클래스 안의 함수는 반드시 첫 번째 인자로 `self`를 받습니다.

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 짖는 행동
    def bark(self):
        print(f"{self.name}: 멍멍!")
    
    # 나이를 먹는 행동
    def add_age(self):
        self.age += 1
        print(f"{self.name}가 한 살 더 먹어서 {self.age}살이 되었습니다.")

# 실습: dog1 뭉치를 짖게 하고, 나이를 한 살 더 먹게 해보세요.
dog1 = Dog("뭉치", 3)

# 아래에 코드를 작성해보세요.
# 1. 짖기


# 2. 나이 먹기

# %% [markdown]
# ---
# ## 3교시: 실전 & 마무리
#
# ### 🏆 [실습 과제] 게임 캐릭터(Character) 클래스 만들기
#
# **요구사항**
# 1. 클래스 이름: `Character`
# 2. `__init__`:
#     * `name`(이름)과 `hp`(체력)을 입력받아 저장합니다.
# 3. 메서드:
#     * `attack()`: "[이름]이 공격합니다!"를 출력합니다.
#     * `take_damage(amount)`: 입력받은 `amount`만큼 `hp`를 줄이고, 남은 체력을 출력합니다.
#
# **직접 코드를 완성하고 아래 테스트 코드를 실행해 보세요.**

# %%
class Character:
    def __init__(self, name, hp):
        # 여기에 코드를 작성하세요 (초기화)
        pass

    def attack(self):
        # 여기에 코드를 작성하세요 (공격)
        pass

    def take_damage(self, amount):
        # 여기에 코드를 작성하세요 (피해 입기)
        pass

# --- 테스트 코드 ---
hero = Character("용사", 100)
hero.attack()            # 출력: 용사이 공격합니다!
hero.take_damage(10)     # 출력 예: 체력이 90 남았습니다.

# %% [markdown]
# ### 👏 고생하셨습니다!
# 이제 클래스의 기본인 **설계도 만들기(`class`), 속성 저장(`__init__`), 행동 정의(`method`)**를 모두 경험하셨습니다.
# 이 기초를 바탕으로 더 복잡한 데이터 분석 도구들도 사실은 이런 클래스들의 집합이라는 것을 이해하시면 됩니다.
